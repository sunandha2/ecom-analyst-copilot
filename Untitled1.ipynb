# %%
import pandas as pd

orders = pd.read_csv('../data/orders.csv')
customers = pd.read_csv('../data/customers.csv')

print(orders.shape)
print(orders.head())
print(orders['category'].value_counts())
print(f"Total revenue: ₹{orders['revenue'].sum():,.0f}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2
# ----> 3 orders = pd.read_csv('../data/orders.csv')
#       4 customers = pd.read_csv('../data/customers.csv')
#       5
#       6 print(orders.shape)
#
# File ~\Downloads\gitdemo\ecom-analyst-copilot\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\Downloads\gitdemo\ecom-analyst-copilot\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\Downloads\gitdemo\ecom-analyst-copilot\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\Downloads\gitdemo\ecom-analyst-copilot\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\Downloads\gitdemo\ecom-analyst-copilot\venv\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/orders.csv'

# %%
import os
print(os.getcwd())  # shows where Jupyter thinks you are
print(os.listdir('../data/'))  # shows what's in data folder
# Out:
# C:\Users\sunandha\Downloads\gitdemo\ecom-analyst-copilot
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
#       2 print(os.getcwd())  # shows where Jupyter thinks you are
# ----> 3 print(os.listdir('../data/'))  # shows what's in data folder
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../data/'

# %%
import os

# See exactly where Jupyter is running from
print("Current location:", os.getcwd())

# Go up one level to project root
os.chdir('..')
print("Moved to:", os.getcwd())

# Create data folder if missing
os.makedirs('data', exist_ok=True)
print("data/ folder ready")

# Confirm
print("Folders here:", os.listdir('.'))
# Out:
# Current location: C:\Users\sunandha\Downloads\gitdemo\ecom-analyst-copilot
# Moved to: C:\Users\sunandha\Downloads\gitdemo
# data/ folder ready
# Folders here: ['data', 'ecom-analyst-copilot', 'salary-truth-hyderabad', 'Urban-Mobility-Intelligence-Uber-Analysis']

# %%
import pandas as pd
import random
from faker import Faker
from datetime import datetime, timedelta

fake = Faker('en_IN')
random.seed(42)

CATEGORIES = ['Electronics', 'Fashion', 'Home & Kitchen', 'Beauty', 'Sports']
PRODUCTS = {
    'Electronics': [('Wireless Earbuds', 2499), ('Phone Case', 399), ('USB Hub', 899), ('Webcam', 3499)],
    'Fashion':     [('Cotton Kurta', 699), ('Sneakers', 1999), ('Sunglasses', 1299), ('Watch', 4999)],
    'Home & Kitchen': [('Air Fryer', 5999), ('Water Bottle', 499), ('Bedsheet Set', 1299), ('Mixer', 3299)],
    'Beauty':      [('Face Serum', 899), ('Lipstick Set', 599), ('Moisturizer', 749), ('Hair Oil', 399)],
    'Sports':      [('Yoga Mat', 999), ('Resistance Bands', 599), ('Protein Shaker', 449), ('Skipping Rope', 299)],
}
CITIES = ['Hyderabad', 'Bangalore', 'Mumbai', 'Delhi', 'Chennai', 'Pune', 'Kolkata']
START_DATE = datetime(2024, 1, 1)

customers = []
for i in range(500):
    customers.append({
        'customer_id': f'CUST{1000+i}',
        'name': fake.name(),
        'email': fake.email(),
        'city': random.choice(CITIES),
        'signup_date': fake.date_between(start_date='-2y', end_date='-6m'),
    })
customers_df = pd.DataFrame(customers)

orders = []
for i in range(3000):
    customer = random.choice(customers)
    category = random.choice(CATEGORIES)
    product_name, base_price = random.choice(PRODUCTS[category])
    order_date = START_DATE + timedelta(days=random.randint(0, 364))
    if order_date.weekday() >= 5:
        base_price = int(base_price * 0.95)
    quantity = random.choices([1, 2, 3], weights=[70, 20, 10])[0]
    revenue = base_price * quantity
    is_returned = random.choices([True, False], weights=[12, 88])[0]
    return_reason = random.choice(['Defective', 'Wrong size', 'Not as described', 'Changed mind']) if is_returned else None
    orders.append({
        'order_id': f'ORD{10000+i}',
        'customer_id': customer['customer_id'],
        'order_date': order_date.strftime('%Y-%m-%d'),
        'product_name': product_name,
        'category': category,
        'quantity': quantity,
        'unit_price': base_price,
        'revenue': revenue,
        'city': customer['city'],
        'is_returned': is_returned,
        'return_reason': return_reason,
        'status': random.choices(['delivered','shipped','cancelled'], weights=[80,12,8])[0],
    })
orders_df = pd.DataFrame(orders)

customers_df.to_csv('data/customers.csv', index=False)
orders_df.to_csv('data/orders.csv', index=False)

print(f"✅ {len(customers_df)} customers saved")
print(f"✅ {len(orders_df)} orders saved")
print(f"✅ Revenue: ₹{orders_df['revenue'].sum():,.0f}")
print(f"✅ Return rate: {orders_df['is_returned'].mean()*100:.1f}%")
# Out:
# ✅ 500 customers saved
# ✅ 3000 orders saved
# ✅ Revenue: ₹6,771,478
# ✅ Return rate: 12.3%

# %%
import os

# Go back into the correct project folder
os.chdir('ecom-analyst-copilot')
print("Now in:", os.getcwd())

# Create data folder inside the right place
os.makedirs('data', exist_ok=True)
print("Folders here:", os.listdir('.'))
# Out:
# Now in: C:\Users\sunandha\Downloads\gitdemo\ecom-analyst-copilot
# Folders here: ['.env', '.git', '.gitignore', '.ipynb_checkpoints', 'app', 'data', 'dbt_project', 'rag', 'README.md', 'requirements.txt', 'Untitled.ipynb', 'Untitled1.ipynb', 'venv']

# %%
import pandas as pd
import random
from faker import Faker
from datetime import datetime, timedelta

fake = Faker('en_IN')
random.seed(42)

CATEGORIES = ['Electronics', 'Fashion', 'Home & Kitchen', 'Beauty', 'Sports']
PRODUCTS = {
    'Electronics': [('Wireless Earbuds', 2499), ('Phone Case', 399), ('USB Hub', 899), ('Webcam', 3499)],
    'Fashion':     [('Cotton Kurta', 699), ('Sneakers', 1999), ('Sunglasses', 1299), ('Watch', 4999)],
    'Home & Kitchen': [('Air Fryer', 5999), ('Water Bottle', 499), ('Bedsheet Set', 1299), ('Mixer', 3299)],
    'Beauty':      [('Face Serum', 899), ('Lipstick Set', 599), ('Moisturizer', 749), ('Hair Oil', 399)],
    'Sports':      [('Yoga Mat', 999), ('Resistance Bands', 599), ('Protein Shaker', 449), ('Skipping Rope', 299)],
}
CITIES = ['Hyderabad', 'Bangalore', 'Mumbai', 'Delhi', 'Chennai', 'Pune', 'Kolkata']
START_DATE = datetime(2024, 1, 1)

customers = []
for i in range(500):
    customers.append({
        'customer_id': f'CUST{1000+i}',
        'name': fake.name(),
        'email': fake.email(),
        'city': random.choice(CITIES),
        'signup_date': fake.date_between(start_date='-2y', end_date='-6m'),
    })
customers_df = pd.DataFrame(customers)

orders = []
for i in range(3000):
    customer = random.choice(customers)
    category = random.choice(CATEGORIES)
    product_name, base_price = random.choice(PRODUCTS[category])
    order_date = START_DATE + timedelta(days=random.randint(0, 364))
    if order_date.weekday() >= 5:
        base_price = int(base_price * 0.95)
    quantity = random.choices([1, 2, 3], weights=[70, 20, 10])[0]
    revenue = base_price * quantity
    is_returned = random.choices([True, False], weights=[12, 88])[0]
    return_reason = random.choice(['Defective', 'Wrong size', 'Not as described', 'Changed mind']) if is_returned else None
    orders.append({
        'order_id': f'ORD{10000+i}',
        'customer_id': customer['customer_id'],
        'order_date': order_date.strftime('%Y-%m-%d'),
        'product_name': product_name,
        'category': category,
        'quantity': quantity,
        'unit_price': base_price,
        'revenue': revenue,
        'city': customer['city'],
        'is_returned': is_returned,
        'return_reason': return_reason,
        'status': random.choices(['delivered','shipped','cancelled'], weights=[80,12,8])[0],
    })
orders_df = pd.DataFrame(orders)

customers_df.to_csv('data/customers.csv', index=False)
orders_df.to_csv('data/orders.csv', index=False)

print(f"✅ {len(customers_df)} customers saved")
print(f"✅ {len(orders_df)} orders saved")
print(f"✅ Revenue: ₹{orders_df['revenue'].sum():,.0f}")
print(f"✅ Return rate: {orders_df['is_returned'].mean()*100:.1f}%")
# Out:
# ✅ 500 customers saved
# ✅ 3000 orders saved
# ✅ Revenue: ₹6,771,478
# ✅ Return rate: 12.3%

# %%
orders = pd.read_csv('data/orders.csv')
customers = pd.read_csv('data/customers.csv')
print(orders.shape)
print(orders.head(3))
# Out:
# (3000, 12)
#    order_id customer_id  order_date  product_name     category  quantity  \
# 0  ORD10000    CUST1026  2024-05-21        Webcam  Electronics         1
# 1  ORD10001    CUST1134  2024-10-09         Watch      Fashion         2
# 2  ORD10002    CUST1483  2024-07-08  Cotton Kurta      Fashion         1
#
#    unit_price  revenue     city  is_returned return_reason     status
# 0        3499     3499     Pune        False           NaN  delivered
# 1        4999     9998   Mumbai        False           NaN  delivered
# 2         699      699  Chennai        False           NaN  delivered
